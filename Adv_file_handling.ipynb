# %% [markdown]
# For binary data like images, audios, videos.
# rb read binary
#
# rw write bonary

# %% [markdown]
# ## Reading a binary data
#
# with open("random_image.jpg", 'rb') as f:
#   data = f.read()
#   print(type(data))
#   print('Size: ', len(data), "bytes")
#   print("Frist 4 bytes:", data[:4])

# %%
## Reading a binary data

with open("plane.jpg", 'rb') as f:
  data = f.read()
  print(type(data))
  print('Size: ', len(data), "bytes")
  print("Frist 4 bytes:", data[:4])
# Out:
# <class 'bytes'>
# Size:  3974 bytes
# Frist 4 bytes: b'\xff\xd8\xff\xe0'

# %%
with open("plane.jpg",'rb') as f:
    img =f.read()
    print(type(img))
    print("size", len(img))
    print("first 4 byted",data[:4])
# Out:
# <class 'bytes'>
# size 3974
# first 4 byted b'\xff\xd8\xff\xe0'

# %%
with open ("plane.jpg", 'rb') as src:
    with open ("pcopy.jpg",'wb') as dist:
        dist.write(src.read())

# %%
# copying a binary file
with open("plane.jpg", "rb") as src:
  with open("photo_copy.jpg", "wb") as dst:
    dst.write(src.read())

# %%
# updating a binary file
with open("image.jpg", "rb") as src:
  with open("photo_copy.jpg", "ab") as dst:
    dst.write(src.read())
print("Binary file updated!")
# Out:
# Binary file updated!

# %%
with open( "poem.txt", 'r') as f:
    ever = f.read()
    print(ever)
# Out:
# Roses are red,
# Violets are blue,
# Python is great,
# An so are you!
# sky is blue,
# I am great,

# %%
with open( "poem.txt", 'r') as f:
    first_7 = f.read(7)
    print(ever)
# Out:
# Roses a

# %%
with open( "poem.txt", 'r') as f:
    first_20 = f.read(20)
    print(first_20)
# Out:
# Roses are red,
# Viole

# %%
with open("poem.txt",'r') as f:
    f_1 = f.readline()
    f_2 = f.readline()
    f_3 = f.readline()
    f_4 = f.readline()
    f_5 = f.readline()
    print(f_1)
    print(f_2)
    print(repr(f_3))
    print(repr(f_4))
    print(f_5)
# Out:
# Roses are red,
#
# Violets are blue,
#
# 'Python is great, \n'
# 'An so are you!\n'
# sky is blue,

# %%
with open("poem.txt",'r') as f:
    line = f.readlines()
    print(type(line))
    print(line)
# Out:
# <class 'list'>
# ['Roses are red,\n', 'Violets are blue, \n', 'Python is great, \n', 'An so are you!\n', 'sky is blue,\n', 'I am great, \n']

# %%
with open("poem.txt",'r') as f:
    line = f.readlines()
    print(line)
# Out:
# ['Roses are red,\n', 'Violets are blue, \n', 'Python is great, \n', 'An so are you!\n', 'sky is blue,\n', 'I am great, \n']

# %%
print('First Line:',repr(line[0]))
print('2nd Line:',line[1])
print('3rd Line:',repr(line[2]))
print(line[3])
print(line[4])
print(line[5])
print(len(line[4]))
# Out:
# First Line: 'Roses are red,\n'
# 2nd Line: Violets are blue,
#
# 3rd Line: 'Python is great, \n'
# An so are you!
#
# sky is blue,
#
# I am great,
#
# 13

# %%
sorted_line = sorted(line)
print(sorted_line)
# Out:
# ['An so are you!\n', 'I am great, \n', 'Python is great, \n', 'Roses are red,\n', 'Violets are blue, \n', 'sky is blue,\n']

# %%
y = sorted(line, key =lambda x :x[1])
print("sorted:",y)
# Out:
# sorted: ['I am great, \n', 'Violets are blue, \n', 'sky is blue,\n', 'An so are you!\n', 'Roses are red,\n', 'Python is great, \n']

# %%
for line in sorted_line:
    print(repr(line))
# Out:
# 'An so are you!\n'
# 'I am great, \n'
# 'Python is great, \n'
# 'Roses are red,\n'
# 'Violets are blue, \n'
# 'sky is blue,\n'

# %%
with open("abani.txt",'w') as f:
    f.write("apples")
    f.write("bananas")
    f.write("guavas")

# %%
with open("abani1.txt",'w') as f:
    f.write("apples\n")
    f.write("bananas\n")
    f.write("guavas\n")

# %%
fruits = ['banana\t','apple\t','oranges\t','guava\t']
with open("fruits.txt",'w') as f:
    f.writelines(fruits)

# %%
fruits = ['banana\n','apple\n','oranges\n','guava\t']
with open("fruits.txt",'w') as f:
    f.writelines(fruits)

# %%
fruits = ['banana\t','apple\t','oranges\t','guava\t']
with open("fruits1.txt",'w') as f:
    f.writelines(fruits)

# %%
fruits = ['oranges\t','guava\t','banana\t','apple\t']
with open("fruits.txt",'w') as f:
    f.writelines(fruits.txt)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[85], line 3
#       1 fruits = ['oranges\t','guava\t','banana\t','apple\t']
#       2 with open("fruits.txt",'w') as f:
# ----> 3     f.writelines(fruits.txt)
#
# AttributeError: 'list' object has no attribute 'txt'

# %%
with open("fruits1.txt",'r') as f:
    f_1 = f.readline()
    f_2 = f.readline()
    f_3 = f.readline()
    f_4 = f.readline()
    print(f_1)
    print(f_2)
    print(repr(f_3))
# Out:
# ''

# %%
## writing different data types

age = 17
gpa = 3.85
subjects = ["Math", "Science", "Python"]
is_passing = True

with open("Student_info.txt", 'w') as f:

  # method 1: str() conversion
  f.write("age: " + str(age) + "\n")

  # fstring
  f.write(f"GPA: {gpa}\n")
  f.write(f"Passing: {is_passing}\n")
