# %%
#Sum of two numbers
def add(a,b):
    return a+b

# %%
addition = add(5,3)
addition
# Out:
# 8

# %%
y = lambda a, b : a+b

# %%
y
# Out:
# <function __main__.<lambda>(a, b)>

# %%
type(y)
# Out:
# function

# %%
addition = lambda a, b : a+b
addition (5,3)
addition (5.0,9.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 addition (5,3)
#       3 addition (5.0,9.0)
# ----> 4 addition (a,b)
#
# NameError: name 'a' is not defined

# %%
#Lambda with one argument
#square of a number
sqr = lambda x: x**2
sqr(9)
# Out:
# 81

# %%
#modulus of a number
mod = lambda c:c%2
mod(27)
# Out:
# 1

# %%
#Floor division
floor = lambda x:x//3
floor (53)
# Out:
# 17

# %%
floor1 = lambda x:x//5
floor1 (53)
# Out:
# 10

# %%
#Lambda with multiple arguments
Area = lambda length, breadth: length*breadth
Area(3,9)
# Out:
# 27

# %%
Volume = lambda x,y,z: x*y*z
Volume(3,6,9)
# Out:
# 162

# %%
Perimeter = lambda a,b:2*a+2*b
Perimeter(4,9)
# Out:
# 26

# %%
# Conditions with lambda 
even_n = lambda x: "even" if x%2 ==0 else "odd"
even_n (91)
# Out:
# 'odd'

# %%
to_upper = lambda s:s.upper()
to_upper("abani")
# Out:
# 'ABANI'

# %%
to_lower = lambda s:s.lower()
to_lower("ABANI")
# Out:
# 'abani'

# %%
def reversed_string(s):
    return s[::-1]
reversed_string("abani bhushan prasad")
# Out:
# 'dasarp nahsuhb inaba'

# %%
reversed_string = lambda s : s[::-1]
reversed_string("abani bhushan prasad")
# Out:
# 'dasarp nahsuhb inaba'

# %%
#use lambda function with sequence datatype:List
cel =[10,20,30,40,50]
far =  list(map(lambda c : c*9/5+32,cel))
far

# %%
type(far)
# Out:
# map

# %%
#use lambda function with sequence datatype:tuple
cel =(10,20,30,40,50)
far =  tuple(map(lambda c : c*9/5+32,cel))
far
# Out:
# (50.0, 68.0, 86.0, 104.0, 122.0)

# %%
type(far)
# Out:
# tuple

# %%
# square all numbers in the list
a = [3,4,7,2,9]
Sqr_a = list(map(lambda c: c**2,a))

# %%
Sqr_a
# Out:
# [9, 16, 49, 4, 81]

# %%
name = ['abani','bhushan','prasad']
upper_name = list(map(lambda x:x.upper(),name))

# %%
upper_name
# Out:
# ['ABANI', 'BHUSHAN', 'PRASAD']

# %%
# Filter
#syntax:filter(function,iterable)
#find the even
no = [1,2,3,4,5,6]
even = list(filter(lambda x : x%2 ==0,no))
even
# Out:
# [2, 4, 6]

# %%
#syntax:filter(function,iterable)
#find the odd
no = [1,2,3,4,5,6]
odd = list(filter(lambda x : x % 2 !=0,no))
odd
# Out:
# [1, 3, 5]

# %%
#filter strings based on lenght more than 4
words = ["Data","science","AI","ML","Machind"]

string_4 =list(filter (lambda s : len(s)>4,words) )
string_4
# Out:
# ['science', 'Machind']

# %%
#filter strings based on lenght less than 4
words = ["Data","science","AI","ML","Machind"]

string_4 =list(filter (lambda s : len(s)<4,words) )
string_4
# Out:
# ['AI', 'ML']

# %%
#filter negative number from the list
no = [-9,3,-4,5,-8,4]
result = list(filter(lambda x : x<0,no))
result
# Out:
# [-9, -4, -8]

# %%
#filter positive number from the list
no = [-9,3,-4,5,-8,4]
result = list(filter(lambda x : x>0,no))
result
# Out:
# [3, 5, 4]

# %%
# give the score greater than 40
students = [
    {"name":"A","marks": 85},
    {"name":"B","marks" : 30},
    {"name":"c","marks" : 90}
]
students
# Out:
# [{'name': 'A', 'marks': 85},
#  {'name': 'B', 'marks': 30},
#  {'name': 'c', 'marks': 90}]

# %%
std = list(filter(lambda x :x["marks"]>40,students))
std
# Out:
# [{'name': 'A', 'marks': 85}, {'name': 'c', 'marks': 90}]

# %%
std = list(filter(lambda x :x["marks"]<40,students))
std
# Out:
# [{'name': 'B', 'marks': 30}]

# %%
###mutable argument as default argument is not good
def add_to_list(item, my_list = []):
    my_list.append(item)
    return my_list

# %%
list1 = add_to_list(1)
list1
# Out:
# [1]

# %%
list2 = add_to_list(2)
list2
# Out:
# [1, 2]

# %%
list5 = add_to_list(5)
list5
# Out:
# [1, 2, 5]

# %%
## sorted(iterable, key)
num = [10,-5,2,-3]
sorted_numbers = sorted(num, key = lambda x: abs(x))

# %%
sorted_numbers
# Out:
# [2, -3, -5, 10]

# %%
sorted(num)
# Out:
# [-5, -3, 2, 10]

# %%
students = [("Rani",78),("Neha",22),("Abani",44),("Baba",98)]

# %%
print(sorted(students))
# Out:
# [('Abani', 44), ('Baba', 98), ('Neha', 22), ('Rani', 78)]

# %%
sorted_students = sorted(students,key = lambda x:x[0])

# %%
sorted_students
# Out:
# [('Abani', 44, 'Patna'),
#  ('Rani', 78, 'Hyderabad'),
#  ('Baba', 98, 'Bhopal'),
#  ('Neha', 22, 'Ahm')]

# %%
sorted_students = sorted(students,key = lambda x:x[1],reverse=True)
sorted_students
# Out:
# [('Baba', 98), ('Rani', 78), ('abani', 44), ('Neha', 22)]

# %%
students = [("Rani",78,"Hyderabad"),("Neha",22,"Ahm"),("Abani",44,"Patna"),("Baba",98,"Bhopal")]

# %%
sorted(students)
# Out:
# [('Abani', 44, 'Patna'),
#  ('Baba', 98, 'Bhopal'),
#  ('Neha', 22, 'Ahm'),
#  ('Rani', 78, 'Hyderabad')]

# %%
sorted_students = sorted(students,key = lambda x:x[2])
sorted_students
# Out:
# [('Neha', 22, 'Ahm'),
#  ('Baba', 98, 'Bhopal'),
#  ('Rani', 78, 'Hyderabad'),
#  ('Abani', 44, 'Patna')]

# %%
sorted_students = sorted(students,key = lambda x:x[2],reverse= True)
sorted_students
# Out:
# [('Abani', 44, 'Patna'),
#  ('Rani', 78, 'Hyderabad'),
#  ('Baba', 98, 'Bhopal'),
#  ('Neha', 22, 'Ahm')]

# %%
help(sorted)
# Out:
# Help on built-in function sorted in module builtins:
#
# sorted(iterable, /, *, key=None, reverse=False)
#     Return a new list containing all items from the iterable in ascending order.
#
#     A custom key function can be supplied to customize the sort order, and the
#     reverse flag can be set to request the result in descending order.

# %%
marks = {
    "Bob":40,
    "Charlie":60,
    "Alice":80
}

# %%
sorted(marks)
# Out:
# ['Alice', 'Bob', 'Charlie']

# %%
marks.keys()
# Out:
# dict_keys(['Bob', 'Charlie', 'Alice'])

# %%
marks.values()
# Out:
# dict_values([40, 60, 80])

# %%
marks.items()
# Out:
# dict_items([('Bob', 40), ('Charlie', 60), ('Alice', 80)])

# %%
sorted_marks = sorted(marks.items(), key = lambda x:x[1])
sorted_marks
# Out:
# [('Bob', 40), ('Charlie', 60), ('Alice', 80)]

# %%
models = [
    {"name":"Randonforest","accuracy":0.89},
    {"name":"SVM","accuracy":0.92},
    {"name":"SGboost","accuracy":0.85}
    
]
models
# Out:
# [{'name': 'Randonforest', 'accuracy': 0.89},
#  {'name': 'SVM', 'accuracy': 0.92},
#  {'name': 'SGboost', 'accuracy': 0.85}]

# %%
models[2]['accuracy']
# Out:
# 0.85

# %%
sort_accuracy = sorted(models, key =lambda x:x['accuracy'],reverse = True)
sort_accuracy
# Out:
# [{'name': 'SVM', 'accuracy': 0.92},
#  {'name': 'Randonforest', 'accuracy': 0.89},
#  {'name': 'SGboost', 'accuracy': 0.85}]

# %%
sort_accuracy = sorted(models, key =lambda x:x['accuracy'],reverse = True)
sort_accuracy
# Out:
# [{'name': 'SVM', 'accuracy': 0.92},
#  {'name': 'Randonforest', 'accuracy': 0.89},
#  {'name': 'SGboost', 'accuracy': 0.85}]
