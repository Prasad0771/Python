# %% [markdown]
# ## Exception handling...

# %% [markdown]
# for seraching use ctrl + f(windows),, mac(command + f)

# %% [markdown]
# ZeroDivisionError: Division by Zero
# TypeError: Operation on incompatible types
# ValueError : Function receive correct type but inapproiate value
# keyError: Dictionary key not found
# IndexError: List index out of range
# AttributeError: Attribute doesn't exist

# %%
a = "string"

a.append("this")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 3
#       1 a = "string"
# ----> 3 a.append("this")
#
# AttributeError: 'str' object has no attribute 'append'

# %%
10 + "20"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 10 + "20"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print("Line 1")

print("Line 2: About to divide")

print(10/0)

print("Line 3: After error")
# Out:
# Line 1
# Line 2: About to divide
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 print("Line 1")
#       3 print("Line 2: About to divide")
# ----> 5 print(10/0)
#       7 print("Line 3: AFter error")
#
# ZeroDivisionError: division by zero

# %%
print("before")

age = int(input("Enter you age: "))
print(age)

print("after")
# Out:
# before
# 0
# after

# %%
print("before executing")

try:
    age = int(input("Enter you age: "))
    print()
except ValueError:
    print("This error occred while entering age")

print("after executing")
# Out:
# before executing
# This error occred while entering age
# after executing

# %% [markdown]
# The try-except block is used to catch and hanlde exceptions, preventing program crashes.

# %%
## Basic Syntax 

try:
    # Code that might raise an exception 
    risky_operation()
except ExceptionType:
    # Code to handle the exception 
    handle_error()

# %%
## 

try: 
    number = int(input("Enter a number: "))
    result = 10/ number
    print(f"Result: {result}")
except ZeroDivisionError:
    print("Error: Cannot divide by zero.")
except ValueError:
    print("Error: Please enter a valid number.")
# Out:
# Error: Please enter a valid number.
# 30

# %%
try:
    x = 10 / "dlkfjs"
except Exception as e:
    print(f"An error occured: {e}")
# Out:
# An error occured: unsupported operand type(s) for /: 'int' and 'str'

# %% [markdown]
# ## Handling Multiple Exceptions
#
# you can handle mutiple exceptions in diff ways.

# %%
data = [1,2,3]
4
# IndexError
# ValueError
# unexpected error;
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 2
#       1 data = [1,2,3]
# ----> 2 index = int(input("Enter index: "))
#       3 print(data[index])
#
# ValueError: invalid literal for int() with base 10: '1.0'

# %%
try:
    data = [1,2,3]
    index = int(input("Enter index: "))
    print(data[index])
except IndexError:
    print("Error: Index given is out of range, given number before 0-2")
except ValueError:
    print("Error: Invalid input! Please enter an integer.")
except Exception as e:
    print(f"Unexpected error: {e}")
# Out:
# Error: Invalid input! Please enter an integer.

# %%
# Tuple of exceptions (same handler)

try:
    value = int(input("Enter a number: "))
    result = 100 / value
except (ValueError, ZeroDivisionError) as e:
    print(f"Input or calculation error: {e}")
# Out:
# Input or calculation error: division by zero

# %%
# getting exeption details 

try:
    file = open("nonexisint.txt", "r")
except FileNotFoundError as e:
    print(f'file error: {e}')
    print(f"Error type: {type(e).__name__}")
# Out:
# file error: [Errno 2] No such file or directory: 'nonexisint.txt'
# Error type: FileNotFoundError

# %% [markdown]
# ## The finally clause
#
# The finally block executes regardless of whether an exception occurred or not. It's commonly used for cleanup
# operations like closing files or database connections.

# %%
try:
    ## code the might raise an exception 
    operation()
except ExceptionType:
    # Handle exception 
    handle_error()
finally:
    ## Always Executes This error occred while entering age
    cleanup()

# %%
file = None 

try:
    file = open("Data.txt", "r")
    content = file.read()
    print(content)
    
except FileNotFoundError:
    print("File not found!")
    
finally:            # Always Executes 
    if file:
        file.close()
        print("File closed successfully...")

# %% [markdown]
# ### The else clause.
#
# The else block executes only if no exception was raised in the only when the try block succeeds.
# try block. It's useful for code that should run.

# %%
## 

try:
    # code that might crash 
    operation()
except Exception Type:
    # handle exception
    handle_error()
else:
    # Excute only if no exception occured 
    Success_operation()
finally:
    # always executes
    cleanup()

# %%
## Division Calculator 

try:
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))
    result = num1/num2 
except ValueError:
    print("Invalid input: please enter number")
except ZeroDivisionError:
    print("Cannot be divide by zero")
else:
    print(f"Result: {result}")
    print("Calculation Successfull!")
finally:
    print("Calculator closed.")
# Out:
# Result: 5.0
# Calculation Successfull!
# Calculator closed.
