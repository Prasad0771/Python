# %%
# Instance Variable and Class variable

# %%
Town = "Panchkula"
class Student:
    School_name = "Bhavan Vidyalaya"
    No_of_students = 0
    def __init__(self,name,roll_no,grade):
        self.name =name
        self.roll_no = roll_no 
        self.grade = grade
        Student.No_of_students +=1
# display studentinfo
    def display_info(self):
        print(f"Name: {self.name}")
        print(f"Roll_Number: {self.roll_no}")
        print(f"grade: {self.grade}")
        print(f"No_of_students: {self.No_of_students}")

# %%
#student1 =Student("Abani", 1001, "MTech")
#student2 =Student("Abhinav", 1002, "MBBS")
student3 =Student("Atharv", 1003, "BTech")

# %%
student1.name

student1.roll_no
# Out:
# 1001

# %%
student2.name

student2.roll_no
# Out:
# 1002

# %%
student1.display_info()
# Out:
# Name: Abani
# Roll_Number: 1001
# grade: MTech
# No_of_students: 4

# %%
student2.display_info()
# Out:
# Name: Abhinav
# Roll_Number: 1002
# grade: MBBS
# No_of_students: 6

# %%
student3.display_info()
# Out:
# Name: Atharv
# Roll_Number: 1003
# grade: BTech
# No_of_students: 7

# %%
Town = "Panchkula"
class Student:
    School_name = "Bhavan Vidyalaya"
    No_of_students = 0
    print(f"No_of_students:{Student.No_of_students}")
  
# display studentinfo
    def display_info(self):
        print(f"Name: {self.name}")
        print(f"Roll_Number: {self.roll_no}")
        print(f"grade: {self.grade}")
        print(f"No_of_students: {self.No_of_students}")
        self.No_of_students +=5
        print(f"No_of_students:{self.No_of_students}")
    def __init__(self,name,roll_no,grade):
        self.name =name
        self.roll_no = roll_no 
        self.grade = grade
        Student.No_of_students +=1
# Out:
# No_of_students:2

# %%
s2 = Student("MMMM",777, "PGCTE")

# %%
s1 = Student("Guruji",777, "PGCTE")

# %%
s = Student("Julie",777, "PGCTE")

# %%
s1.display_info()
# Out:
# Name: Guruji
# Roll_Number: 777
# grade: PGCTE
# No_of_students: 1
# No_of_students:6

# %%
s1.display_info()
# Out:
# Name: Guruji
# Roll_Number: 777
# grade: PGCTE
# No_of_students: 6
# No_of_students:11

# %%
student4 =Student("Madan", 1003, "BTech")

# %%
student4.display_info()
# Out:
# Name: Madan
# Roll_Number: 1003
# grade: BTech
# No_of_students: 2

# %%
student4 =Student("Madan", 1003, "BTech")

# %%
student4.display_info()
# Out:
# Name: Madan
# Roll_Number: 1003
# grade: BTech
# No_of_students: 3
